# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx

# %%
df = pd.read_csv('slash.txt',sep='\t')

# %%
df['Sign'].value_counts()
# Out:
#  1    425072
# -1    124130
# Name: Sign, dtype: int64

# %%
G = nx.DiGraph()
for index,rows in df.iterrows():
    u = rows['FromNodeId']
    v = rows['ToNodeId']
    s = rows['Sign']
    G.add_edge(u,v,sign=s)

# %%
in_pos = {}
in_neg = {}

for nodes in G.nodes():
    l = list(G.in_edges(nodes,data=True))
    pos=[]
    neg=[]
    for items in l:
        if items[2]['sign'] == 1:
            pos.append(items[0])
        else:
            neg.append(items[0])
    in_pos[nodes] = pos
    in_neg[nodes] = neg

# %%
out_pos = {}
out_neg = {}
for nodes in G.nodes():
    pos = []
    neg = []
    l = dict(G[nodes])
    for keys in l:
        if(l[keys]['sign'] == 1):
            pos.append(keys)
        else:
            neg.append(keys)
    out_pos[nodes] = pos
    out_neg[nodes] = neg

# %%
uip_vip = {}
uip_vin = {}
uin_vip = {}
uin_vin = {}
uip_vop = {}
uip_von = {}
uin_vop = {}
uin_von = {}
uop_vip = {}
uop_vin = {}
uon_vip = {}
uon_vin = {}
uop_vop = {}
uop_von = {}
uon_vop = {}
uon_von = {}
X = dict(G.nodes(data=True))
edge_list = list(G.edges())
for edge in edge_list:
    u = edge[0]
    v = edge[1]
    uip = in_pos[u]
    uin = in_neg[u]
    uop = out_pos[u]
    uon = out_neg[u]
    vip = in_pos[v]
    vin = in_neg[v]
    vop = out_pos[v]
    von = out_neg[v]
    
    
    uip_vipx = len(list(set(uip) & set(vip)))
    uip_vinx = len(list(set(uip) & set(vin)))
    uin_vipx = len(list(set(uin) & set(vip)))
    uin_vinx = len(list(set(uin) & set(vin)))
    uip_vopx = len(list(set(uip) & set(vop)))
    uip_vonx = len(list(set(uip) & set(von)))
    uin_vopx = len(list(set(uin) & set(vop)))
    uin_vonx = len(list(set(uin) & set(von)))
    uop_vipx = len(list(set(uop) & set(vip)))
    uop_vinx = len(list(set(uop) & set(vin)))
    uon_vipx = len(list(set(uon) & set(vip)))
    uon_vinx = len(list(set(uon) & set(vin)))
    uop_vopx = len(list(set(uop) & set(vop)))
    uop_vonx = len(list(set(uop) & set(von)))
    uon_vopx = len(list(set(uon) & set(vop)))
    uon_vonx = len(list(set(uon) & set(von)))
    uip_vip[edge]=uip_vipx
    uip_vin[edge]=uip_vinx
    uin_vip[edge]=uin_vipx
    uin_vin[edge]=uin_vinx
    uip_vop[edge]=uip_vopx
    uip_von[edge]=uip_vonx
    uin_vop[edge]=uin_vopx
    uin_von[edge]=uin_vonx
    uop_vip[edge]=uop_vipx
    uop_vin[edge]=uop_vinx
    uon_vip[edge]=uon_vipx
    uon_vin[edge]=uon_vinx
    uop_vop[edge]=uop_vopx
    uop_von[edge]=uop_vonx
    uon_vop[edge]=uon_vopx
    uon_von[edge]=uon_vonx

    
nx.set_edge_attributes(G,uip_vip,"uip_vip")
nx.set_edge_attributes(G,uip_vin,"uip_vin")
nx.set_edge_attributes(G,uin_vip,"uin_vip")
nx.set_edge_attributes(G,uin_vin,"uin_vin")
nx.set_edge_attributes(G,uip_vop,"uip_vop")
nx.set_edge_attributes(G,uip_von,"uip_von")
nx.set_edge_attributes(G,uin_vop,"uin_vop")
nx.set_edge_attributes(G,uin_von,"uin_von")
nx.set_edge_attributes(G,uop_vip,"uop_vip")
nx.set_edge_attributes(G,uop_vin,"uop_vin")
nx.set_edge_attributes(G,uon_vip,"uon_vip")
nx.set_edge_attributes(G,uon_vin,"uon_vin")
nx.set_edge_attributes(G,uop_vop,"uop_vop")
nx.set_edge_attributes(G,uop_von,"uop_von")
nx.set_edge_attributes(G,uon_vop,"uon_vop")
nx.set_edge_attributes(G,uon_von,"uon_von")

# %%
for keys in (list(G.edges(data=True))[0][2]):
    print(keys + "[edge]=" +keys + "x")
# Out:
# sign[edge]=signx
# uip_vip[edge]=uip_vipx
# uip_vin[edge]=uip_vinx
# uin_vip[edge]=uin_vipx
# uin_vin[edge]=uin_vinx
# uip_vop[edge]=uip_vopx
# uip_von[edge]=uip_vonx
# uin_vop[edge]=uin_vopx
# uin_von[edge]=uin_vonx
# uop_vip[edge]=uop_vipx
# uop_vin[edge]=uop_vinx
# uon_vip[edge]=uon_vipx
# uon_vin[edge]=uon_vinx
# uop_vop[edge]=uop_vopx
# uop_von[edge]=uop_vonx
# uon_vop[edge]=uon_vopx
# uon_von[edge]=uon_vonx

# %%
df = pd.DataFrame(columns=[
'edge',
'uip_vip',
'uip_vin',
'uin_vip',
'uin_vin',
'uip_vop',
'uip_von',
'uin_vop',
'uin_von',
'uop_vip',
'uop_vin',
'uon_vip',
'uon_vin',
'uop_vop',
'uop_von',
'uon_vop',
'uon_von',
'sign'])

# %%
for keys in (list(G.edges(data=True))[0][2]):
    print("df['" + keys + "']=" + keys + ".values()")
# Out:
# df['sign']=sign.values()
# df['uip_vip']=uip_vip.values()
# df['uip_vin']=uip_vin.values()
# df['uin_vip']=uin_vip.values()
# df['uin_vin']=uin_vin.values()
# df['uip_vop']=uip_vop.values()
# df['uip_von']=uip_von.values()
# df['uin_vop']=uin_vop.values()
# df['uin_von']=uin_von.values()
# df['uop_vip']=uop_vip.values()
# df['uop_vin']=uop_vin.values()
# df['uon_vip']=uon_vip.values()
# df['uon_vin']=uon_vin.values()
# df['uop_vop']=uop_vop.values()
# df['uop_von']=uop_von.values()
# df['uon_vop']=uon_vop.values()
# df['uon_von']=uon_von.values()
# df['embed']=embed.values()

# %%
embed = {}
for edge in list(G.edges()):
    inward_i=[]
    inward_j=[]
    outward_i=[]
    outward_j=[]
    for items in list(G.in_edges(edge[0])):
        inward_i.append(items[0])
    for items in list(G.in_edges(edge[1])):
        inward_j.append(items[0])
    for keys in dict(G[edge[0]]):
        outward_i.append(keys)
    for keys in dict(G[edge[1]]):
        outward_j.append(keys)
    final_i = list(set(inward_i) | set(inward_j))
    final_j = list(set(outward_i) | set(outward_j))
    final = list(set(final_i) & set(final_j)) 
    embed[edge] = len(final)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-111-b59d23dcf64d> in <module>()
#       5     outward_i=[]
#       6     outward_j=[]
# ----> 7     for items in list(G.in_edges(edge[0])):
#       8         inward_i.append(items[0])
#       9     for items in list(G.in_edges(edge[1])):
#
# ~/anaconda3/lib/python3.6/site-packages/networkx/classes/reportviews.py in <genexpr>(.0)
#     742     def __iter__(self):
#     743         return (self._report(nbr, n, dd) for n, nbrs in self._nodes_nbrs()
# --> 744                 for nbr, dd in nbrs.items())
#     745
#     746     def __contains__(self, e):
#
# KeyboardInterrupt:

# %%
nx.set_edge_attributes(G,embed,"embed")

# %%
uip_vip=nx.get_edge_attributes(G,'uip_vip')
uip_vin=nx.get_edge_attributes(G,'uip_vin')
uin_vip=nx.get_edge_attributes(G,'uin_vip')
uin_vin=nx.get_edge_attributes(G,'uin_vin')
uip_vop=nx.get_edge_attributes(G,'uip_vop')
uip_von=nx.get_edge_attributes(G,'uip_von')
uin_vop=nx.get_edge_attributes(G,'uin_vop')
uin_von=nx.get_edge_attributes(G,'uin_von')
uop_vip=nx.get_edge_attributes(G,'uop_vip')
uop_vin=nx.get_edge_attributes(G,'uop_vin')
uon_vip=nx.get_edge_attributes(G,'uon_vip')
uon_vin=nx.get_edge_attributes(G,'uon_vin')
uop_vop=nx.get_edge_attributes(G,'uop_vop')
uop_von=nx.get_edge_attributes(G,'uop_von')
uon_vop=nx.get_edge_attributes(G,'uon_vop')
uon_von=nx.get_edge_attributes(G,'uon_von')
embed = nx.get_edge_attributes(G, 'embed')

# %%
df['edge']=uip_vip.keys()
df['uip_vip']=uip_vip.values()
df['uip_vin']=uip_vin.values()
df['uin_vip']=uin_vip.values()
df['uin_vin']=uin_vin.values()
df['uip_vop']=uip_vop.values()
df['uip_von']=uip_von.values()
df['uin_vop']=uin_vop.values()
df['uin_von']=uin_von.values()
df['uop_vip']=uop_vip.values()
df['uop_vin']=uop_vin.values()
df['uon_vip']=uon_vip.values()
df['uon_vin']=uon_vin.values()
df['uop_vop']=uop_vop.values()
df['uop_von']=uop_von.values()
df['uon_vop']=uon_vop.values()
df['uon_von']=uon_von.values()
df['embed'] = embed.values()
signCol=nx.get_edge_attributes(G,'sign')
df['sign'] = signCol.values()

# %%
df
# Out:
#                   edge  uip_vip  uip_vin  uin_vip  uin_vin  uip_vop  uip_von  \
# 0               (0, 1)        9        0        0        0        5        0
# 1               (0, 2)        3        0        1        0        0        0
# 2               (0, 3)       14        1        0        2        2        0
# 3               (0, 4)        4        1        0        0        0        0
# 4               (0, 5)        3        0        0        0        1        1
# 5               (0, 6)        0        0        0        0        0        0
# 6               (0, 7)        0        0        0        0        0        0
# 7               (0, 8)       45        1        1        7       12        1
# 8               (0, 9)       32        1        0        4        6        0
# 9              (0, 10)        3        0        0        0        2        0
# 10             (0, 11)        8        0        0        0       13        0
# 11             (0, 12)        0        0        0        0        0        0
# 12             (0, 13)        0        0        0        1        0        0
# 13             (0, 14)        3        0        0        0        7        0
# 14             (0, 15)        7        0        1        0        0        0
# 15             (0, 16)        1        0        0        0        0        0
# 16             (0, 17)       80        0        1       10        5        0
# 17             (0, 18)        2        0        0        0        3        0
# 18             (0, 19)        2        0        0        0        3        0
# 19             (0, 20)        0        0        0        0        0        0
# 20             (0, 21)        6        1        3        1        3        0
# 21             (0, 22)        6        0        0        0        0        0
# 22             (0, 23)        0        0        0        0        0        0
# 23             (0, 24)        1        0        0        0        0        0
# 24             (0, 25)        1        1        0        0        0        2
# 25             (0, 26)        0        0        0        0        0        0
# 26             (0, 27)        0        0        1        0        0        0
# 27             (0, 28)        0        1        0        0        0        0
# 28             (0, 29)        1        5        1        0        2        0
# 29              (1, 0)        9        0        0        0        0        0
# ...                ...      ...      ...      ...      ...      ...      ...
# 549172  (82112, 76716)        0        0        0        0        0        0
# 549173  (82113, 76730)        0        0        0        0        0        0
# 549174  (82115, 81554)        0        0        0        0        0        0
# 549175  (82116, 76813)        0        0        0        0        0        0
# 549176  (82117, 76850)        0        0        0        0        0        0
# 549177  (82118, 76873)        0        0        0        0        0        0
# 549178  (82119, 77132)        0        0        0        0        0        0
# 549179  (82119, 82120)        0        0        0        0        0        0
# 549180  (82119, 82121)        0        0        0        0        0        0
# 549181  (82122, 81615)        0        0        0        0        0        0
# 549182  (82124, 81624)        0        0        0        0        0        0
# 549183  (82125, 78027)        0        0        0        0        0        0
# 549184  (82126, 78053)        0        0        0        0        0        0
# 549185  (82126, 78054)        0        0        0        0        0        0
# 549186  (82128, 78170)        0        0        0        0        0        0
# 549187  (82129, 78443)        0        0        0        0        0        0
# 549188  (82130, 78568)        0        0        0        0        0        0
# 549189  (82131, 79090)        0        0        0        0        0        0
# 549190  (82132, 79454)        0        0        0        0        0        0
# 549191  (82133, 79821)        0        0        0        0        0        0
# 549192  (82134, 79934)        0        0        0        0        0        0
# 549193  (82135, 80173)        0        0        0        0        0        0
# 549194  (82137, 80569)        0        0        0        0        0        0
# 549195  (82138, 81502)        0        0        0        0        0        0
# 549196  (82139, 81584)        0        0        0        0        0        0
# 549197  (82140, 81612)        0        0        0        0        0        0
# 549198  (82141, 82129)        0        0        0        0        0        0
# 549199  (82141, 82142)        0        0        0        0        0        0
# 549200  (82143, 81974)        0        0        0        0        0        0
# 549201  (82143, 82136)        0        0        0        0        0        0
#
#         uin_vop  uin_von  uop_vip  uop_vin  uon_vip  uon_vin  uop_vop  \
# 0             0        1        0        0        0        0        2
# 1             0        0        0        0        0        0        0
# 2             0        0        2        0        0        0        3
# 3             0        0        1        0        0        0        0
# 4             0        0        1        0        0        0        1
# 5             0        0        0        0        0        0        0
# 6             0        0        0        0        0        0        0
# 7             0        0        5        0        0        0        4
# 8             0        0        6        0        0        0        1
# 9             0        0        1        0        0        0        1
# 10            0        0        0        0        0        0        3
# 11            0        0        0        0        0        0        0
# 12            0        0        0        0        0        0        0
# 13            0        1        0        0        0        0        2
# 14            0        0        1        0        0        0        0
# 15            0        0        0        0        0        0        0
# 16            0        0        5        0        0        0        3
# 17            0        0        1        0        0        0        2
# 18            0        0        1        0        0        0        2
# 19            0        0        0        0        0        0        0
# 20            0        0        0        0        0        0        1
# 21            0        0        1        0        0        0        0
# 22            0        0        0        0        0        0        0
# 23            0        0        0        0        0        0        0
# 24            0        1        0        0        1        0        0
# 25            0        0        0        0        0        0        0
# 26            0        0        0        0        0        0        0
# 27            0        0        0        0        0        0        0
# 28            1        0        0        1        0        0        0
# 29            0        0        5        0        0        1        2
# ...         ...      ...      ...      ...      ...      ...      ...
# 549172        0        0        0        0        0        0        0
# 549173        0        0        0        0        0        0        0
# 549174        0        0        0        0        0        0        0
# 549175        0        0        0        0        0        0        0
# 549176        0        0        0        0        0        0        0
# 549177        0        0        0        0        0        0        0
# 549178        0        0        0        0        0        0        0
# 549179        0        0        0        0        0        0        0
# 549180        0        0        0        0        0        0        0
# 549181        0        0        0        0        0        0        0
# 549182        0        0        0        0        0        0        0
# 549183        0        0        0        0        0        0        0
# 549184        0        0        0        0        0        0        0
# 549185        0        0        0        0        0        0        0
# 549186        0        0        0        0        0        0        0
# 549187        0        0        0        0        0        0        0
# 549188        0        0        0        0        0        0        0
# 549189        0        0        0        0        0        0        0
# 549190        0        0        0        0        0        0        0
# 549191        0        0        0        0        0        0        0
# 549192        0        0        0        0        0        0        0
# 549193        0        0        0        0        0        0        0
# 549194        0        0        0        0        0        0        0
# 549195        0        0        0        0        0        0        0
# 549196        0        0        0        0        0        0        0
# 549197        0        0        0        0        0        0        0
# 549198        0        0        0        0        0        0        0
# 549199        0        0        0        0        0        0        0
# 549200        0        0        0        0        0        0        1
# 549201        0        0        1        0        0        0        0
#
#         uop_von  uon_vop  uon_von  sign  embed
# 0             0        0        0     1     42
# 1             0        0        0     1     13
# 2             0        0        0     1     16
# 3             0        0        0     1     13
# 4             0        0        0     1     18
# 5             0        0        0     1     16
# 6             0        0        0     1     15
# 7             0        0        0     1    102
# 8             0        0        0     1     34
# 9             0        0        0     1     20
# 10            0        0        0     1    102
# 11            0        0        0     1     13
# 12            0        0        0     1     14
# 13            0        0        1     1     36
# 14            0        0        0     1     15
# 15            0        0        0     1     34
# 16            0        0        0     1     30
# 17            0        0        0     1     16
# 18            0        0        0     1     19
# 19            0        0        0     1     13
# 20            0        0        0     1     44
# 21            0        0        0     1     14
# 22            0        0        0     1     13
# 23            0        0        0     1     15
# 24            0        0        0    -1     26
# 25            0        0        0    -1     15
# 26            0        0        0    -1     13
# 27            0        0        0    -1     13
# 28            0        1        0    -1     31
# 29            0        0        0     1     42
# ...         ...      ...      ...   ...    ...
# 549172        0        0        0     1      1
# 549173        0        0        0     1      0
# 549174        0        0        0     1      0
# 549175        0        0        0     1      0
# 549176        0        0        0     1      0
# 549177        0        0        0     1      0
# 549178        0        0        0     1      0
# 549179        0        0        0     1      0
# 549180        0        0        0     1      0
# 549181        0        0        0     1      0
# 549182        0        0        0     1      0
# 549183        0        0        0     1      1
# 549184        0        0        0     1      0
# 549185        0        0        0     1      2
# 549186        0        0        0     1      0
# 549187        0        0        0     1      0
# 549188        0        0        0     1      0
# 549189        0        0        0     1      0
# 549190        0        0        0     1      0
# 549191        0        0        0     1      1
# 549192        0        0        0     1      0
# 549193        0        0        0     1      0
# 549194        0        0        0     1      0
# 549195        0        0        0     1      0
# 549196        0        0        0     1      0
# 549197        0        0        0     1      0
# 549198        0        0        0     1      0
# 549199        0        0        0     1      0
# 549200        0        0        0     1      0
# 549201        0        0        0     1      1
#
# [549202 rows x 19 columns]

# %%
from sklearn.model_selection import train_test_split
X = df.drop(['edge','sign','embed'],axis=1)
y = df['sign']

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %%
lr = LogisticRegression()
lr.fit(X_train,y_train)
pred = lr.predict(X_test)
lr.score(X_test,y_test)
# Out:
# 0.8059103613404831

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,pred)
# Out:
# array([[ 5151, 19806],
#        [ 1513, 83371]])

# %%
ann = MLPClassifier()
ann.fit(X_train,y_train)
ann.score(X_test,y_test)
# Out:
# /home/sudhanshu/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# 0.818009668520862

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)
dt.score(X_test,y_test)
# Out:
# 0.8093516992744058

# %%
import xgboost as xgb
xg = xgb.XGBClassifier()
xg.fit(X_train,y_train)
xg.score(X_test,y_test)
# Out:
# /home/sudhanshu/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# 0.8757465404224326

# %%
#VARYING EMBEDDEDNESS TO IMPROVE LEARNING

# df = df.loc[df.embed>=25]

# from sklearn.model_selection import train_test_split
# X = df.drop(['edge','sign','embed'],axis=1)
# y = df['sign']

# X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# lr = LogisticRegression()
# lr.fit(X_train,y_train)
# pred = lr.predict(X_test)
# lr.score(X_test,y_test)

# df = df.loc[df.embed>=10]
# df.shape

# from sklearn.model_selection import train_test_split
# X = df.drop(['edge','sign','embed'],axis=1)
# y = df['sign']

# X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# lr = LogisticRegression()
# lr.fit(X_train,y_train)
# pred = lr.predict(X_test)
# lr.score(X_test,y_test)

# %%
from sklearn.model_selection import KFold

# %%
 kf = KFold(n_splits=10)

# %%
for train_index, test_index in kf.split(X,y):
    #print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    lr = LogisticRegression()
    lr.fit(X_train,y_train)
    pred = lr.predict(X_test)
    print(lr.score(X_test,y_test))
# Out:
# 0.8644780684983886
# 0.8552648349447388
# 0.7849235251274581
# 0.7699563000728332
# 0.7942279679533868
# 0.7808448652585579
# 0.7533321194464676
# 0.7811361981063365
# 0.8180080116533139
# 0.8738164603058995

# %%
lr = LogisticRegression()
lr.fit(X_train,y_train)
pred = lr.predict(X_test)
lr.score(X_test,y_test)
# Out:
# 0.8738164603058995

# %%
X_train.shape
# Out:
# (494282, 16)

# %%
X_test.shape
# Out:
# (54920, 16)
